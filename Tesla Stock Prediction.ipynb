# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn

# %%
data = pd.read_csv('data/TSLA.csv')
data.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2020-10-12  442.000000  448.739990  438.579987  442.299988  442.299988
# 1  2020-10-13  443.350006  448.890015  436.600006  446.649994  446.649994
# 2  2020-10-14  449.779999  465.899994  447.350006  461.299988  461.299988
# 3  2020-10-15  450.309998  456.570007  442.500000  448.880005  448.880005
# 4  2020-10-16  454.440002  455.950012  438.850006  439.670013  439.670013
#
#      Volume
# 0  38791100
# 1  34463700
# 2  47879700
# 3  35672400
# 4  32775900

# %%
close = data['Close']
plt.figure(figsize=(10,10))
ax = close.plot(title='Tesla')
ax.set_xlabel('Date')
ax.set_ylabel('CLose')
plt.show()

# %%
x = data[['Open', 'High', 'Low']]
y = data['Close']forcast[["ds", "yhat", "yhat_lower", "yhat_upper"]].tail()

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3)
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)
y_pred[0:5]
# Out:
# array([703.42354145, 655.39762947, 706.26543625, 449.16744977,
#        692.53122892])
